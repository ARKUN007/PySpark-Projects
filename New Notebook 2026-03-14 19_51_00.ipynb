# %%
from pyspark.sql.types import StringType, IntegerType, FloatType, StructType, StructField
from pyspark.sql.functions import 

data = [
(1,'Phone',500,2,'2024-01-01'),
(2,'Laptop',1000,1,'2024-01-02'),
(3,'Tablet',300,3,'2024-01-03'),
(4,'Phone',500,1,'2024-01-04'),
(5,'Laptop',1000,2,'2024-01-05')
]

schema = StuctType([
    StuctField('id', dataType.IntegerType(), True),
    StructField('product', dataType.StringType(), True),
    StructField('price', dataType.IntegerType(), True),
    StructField('quantity', dataType.IntegerType(), True),
    StructField('date', dataType.StringType(), True)
])

df = spark.createDataFrame(data, schema)

df.show(truncate = False)
